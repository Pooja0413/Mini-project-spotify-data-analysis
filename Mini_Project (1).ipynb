# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_track=pd.read_csv("/content/tracks.csv")
df_track.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450  0.0   -13.338   1.0       0.4510
# 1   1922-06-01         0.695  0.2630  0.0   -22.136   1.0       0.9570
# 2   1922-03-21         0.434  0.1770  1.0   -21.180   1.0       0.0512
# 3   1922-03-21         0.321  0.0946  7.0   -27.961   1.0       0.0504
# 4         1922         0.402  0.1580  3.0   -16.900   0.0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851             3.0
# 1         0.797            0.0000     0.148    0.655  102.009             1.0
# 2         0.994            0.0218     0.212    0.457  130.418             5.0
# 3         0.995            0.9180     0.104    0.397  169.980             3.0
# 4         0.989            0.1300     0.311    0.196  103.220             4.0

# %%
#check null values
df_track.isnull().sum()
# Out:
# id                  0
# name                0
# popularity          0
# duration_ms         0
# explicit            0
# artists             0
# id_artists          0
# release_date        0
# danceability        1
# energy              1
# key                 1
# loudness            1
# mode                1
# speechiness         1
# acousticness        1
# instrumentalness    1
# liveness            1
# valence             1
# tempo               1
# time_signature      1
# dtype: int64

# %%
df_track.shape
# Out:
# (34468, 20)

# %%
df_track.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450  0.0   -13.338   1.0       0.4510
# 1   1922-06-01         0.695  0.2630  0.0   -22.136   1.0       0.9570
# 2   1922-03-21         0.434  0.1770  1.0   -21.180   1.0       0.0512
# 3   1922-03-21         0.321  0.0946  7.0   -27.961   1.0       0.0504
# 4         1922         0.402  0.1580  3.0   -16.900   0.0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851             3.0
# 1         0.797            0.0000     0.148    0.655  102.009             1.0
# 2         0.994            0.0218     0.212    0.457  130.418             5.0
# 3         0.995            0.9180     0.104    0.397  169.980             3.0
# 4         0.989            0.1300     0.311    0.196  103.220             4.0

# %%
sort_df=df_track.sort_values("popularity",ascending=True)
sort_df.head()
# Out:
#                            id                                   name  \
# 17233  37VN7v6vIgYMzc0u1OWFWS        Mata Mata Meri Mata Bharat Mata
# 14419  126RPwy75yPCLViSiOYvMN                   Perivoli m' orgomeno
# 14418  1267M9JOoAvhg6zeQmUy4r                  What More Do You Want
# 14417  124FvVQk5uz242rjvZaAjp             Mpravo gia ti mastoria sou
# 14416  11oGzep0OFTrmEXeoFN5HL  Sto eipa stin Patra na min pas Vasilo
#
#        popularity  duration_ms  explicit  \
# 17233           0       171899         0
# 14419           0       196653         0
# 14418           0       358147         0
# 14417           0       189987         0
# 14416           0       142240         0
#
#                                                  artists  \
# 17233                      ['Shamshad Begum', 'Motilal']
# 14419  ['Rita Ampatzi', 'Xaralampos Margelis', 'Klari...
# 14418                                   ['The Gns Band']
# 14417                              ['Markos Vamvakaris']
# 14416                                   ['Saltoy Maria']
#
#                                               id_artists release_date  \
# 17233  ['0Ury0QIiBOlJmsdYUiCTfQ', '6eEJmNVu2oI9ahBwpJ...   1943-01-01
# 14419  ['0iqQBxiXR0b5Azp3qwwF2e', '0zaCkdetGJvJQ2soAu...   1940-01-01
# 14418                         ['1DqyTf8NSvsBC2bmWJVWdS']         1940
# 14417                         ['2MOeRxQqwrvur6it4B3G3R']   1940-01-01
# 14416                         ['119LRJM9Ner3Qmm2ofkuTg']   1940-01-01
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 17233         0.578   0.155  3.0   -10.258   0.0       0.2200         0.992
# 14419         0.382   0.537  9.0    -8.364   0.0       0.0355         0.758
# 14418         0.433   0.728  2.0   -11.381   1.0       0.0710         0.627
# 14417         0.630   0.322  0.0   -13.138   0.0       0.0792         0.995
# 14416         0.580   0.494  7.0    -9.081   0.0       0.0585         0.954
#
#        instrumentalness  liveness  valence    tempo  time_signature
# 17233          0.253000     0.658    0.557   69.065             4.0
# 14419          0.001370     0.146    0.776  111.161             3.0
# 14418          0.038700     0.212    0.504  104.630             4.0
# 14417          0.666000     0.336    0.784  100.578             4.0
# 14416          0.000287     0.294    0.652   82.977             4.0

# %%
df_track.describe().transpose()
# Out:
#                     count           mean            std     min  \
# popularity        34468.0       7.431066      11.730337     0.0
# duration_ms       34468.0  209486.855692  150112.594669  3344.0
# explicit          34468.0       0.002176       0.046597     0.0
# danceability      34467.0       0.516346       0.173212     0.0
# energy            34467.0       0.277972       0.176293     0.0
# key               34467.0       5.090841       3.457716     0.0
# loudness          34467.0     -14.810371       5.422802   -60.0
# mode              34467.0       0.708823       0.454312     0.0
# speechiness       34467.0       0.163984       0.270552     0.0
# acousticness      34467.0       0.861000       0.198558     0.0
# instrumentalness  34467.0       0.287583       0.377633     0.0
# liveness          34467.0       0.212392       0.161437     0.0
# valence           34467.0       0.527306       0.264135     0.0
# tempo             34467.0     110.202531      31.315847     0.0
# time_signature    34467.0       3.759596       0.667010     0.0
#
#                             25%           50%          75%          max
# popularity             0.000000       0.00000      12.0000       77.000
# duration_ms       153507.000000  181740.00000  207884.7500  3577800.000
# explicit               0.000000       0.00000       0.0000        1.000
# danceability           0.389000       0.53100       0.6560        0.957
# energy                 0.152000       0.24600       0.3660        1.000
# key                    2.000000       5.00000       8.0000       11.000
# loudness             -18.243000     -14.06300     -10.9080        3.855
# mode                   0.000000       1.00000       1.0000        1.000
# speechiness            0.039300       0.05140       0.1020        0.970
# acousticness           0.819000       0.95000       0.9880        0.996
# instrumentalness       0.000003       0.00975       0.7240        0.999
# liveness               0.109000       0.15100       0.2680        0.999
# valence                0.313000       0.55000       0.7460        1.000
# tempo                 84.821000     107.71100     128.3965      221.741
# time_signature         4.000000       4.00000       4.0000        5.000

# %%
most_popular=df_track[df_track["popularity"]>90].sort_values(by="popularity",ascending=False)
most_popular.head()
# Out:
# Empty DataFrame
# Columns: [id, name, popularity, duration_ms, explicit, artists, id_artists, release_date, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature]
# Index: []

# %%
df_track[["artists"]].iloc[18]
# Out:
# artists    ['Victor Boucher']
# Name: 18, dtype: object

# %%
df_track["duration"]=df_track["duration_ms"].apply(lambda x:round(x/1000))
df_track.drop("duration_ms",inplace=True,axis=1)

# %%
df_track.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.645  0.4450  0.0   -13.338   1.0       0.4510         0.674
# 1         0.695  0.2630  0.0   -22.136   1.0       0.9570         0.797
# 2         0.434  0.1770  1.0   -21.180   1.0       0.0512         0.994
# 3         0.321  0.0946  7.0   -27.961   1.0       0.0504         0.995
# 4         0.402  0.1580  3.0   -16.900   0.0       0.0390         0.989
#
#    instrumentalness  liveness  valence    tempo  time_signature  duration
# 0            0.7440     0.151    0.127  104.851             3.0       127
# 1            0.0000     0.148    0.655  102.009             1.0        98
# 2            0.0218     0.212    0.457  130.418             5.0       182
# 3            0.9180     0.104    0.397  169.980             3.0       177
# 4            0.1300     0.311    0.196  103.220             4.0       163

# %%
#who has most monthly listeners?
df_track["artists"].value_counts()
# Out:
# ['Francisco Canaro']                                         846
# ['Tadeusz Dolega Mostowicz']                                 661
# ['Ignacio Corsini']                                          537
# ['Billie Holiday']                                           415
# ['Georgette Heyer', 'Irina Salkow']                          400
#                                                             ...
# ['Joan Leslie', 'Dennis Morgan', 'Spike Jones Orchestra']      1
# ['Bette Davis', 'Spike Jones Orchestra']                       1
# ['Errol Flynn', 'Spike Jones Orchestra']                       1
# ['Helge Leonhard']                                             1
# ['Rudi Carrell']                                               1
# Name: artists, Length: 6944, dtype: int64

# %%
df_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34468 entries, 0 to 34467
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                34468 non-null  object
#  1   name              34468 non-null  object
#  2   popularity        34468 non-null  int64
#  3   explicit          34468 non-null  int64
#  4   artists           34468 non-null  object
#  5   id_artists        34468 non-null  object
#  6   release_date      34468 non-null  object
#  7   danceability      34467 non-null  float64
#  8   energy            34467 non-null  float64
#  9   key               34467 non-null  float64
#  10  loudness          34467 non-null  float64
#  11  mode              34467 non-null  float64
#  12  speechiness       34467 non-null  float64
#  13  acousticness      34467 non-null  float64
#  14  instrumentalness  34467 non-null  float64
#  15  liveness          34467 non-null  float64
#  16  valence           34467 non-null  float64
#  17  tempo             34467 non-null  float64
#  18  time_signature    34467 non-null  float64
#  19  duration          34468 non-null  int64
# dtypes: float64(12), int64(3), object(5)
# memory usage: 5.3+ MB

# %%
df_track[df_track["duration"]==5621]["artists"]
# Out:
# Series([], Name: artists, dtype: object)

# %%
corr_df=df_track.drop(["key","mode","explicit"],axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(corr_df,annot=True,vmin=1,vmax=1,center=0,cmap="inferno")
heatmap.set_title("Corr heatmap between variable")
heatmap.set_xticklabels(heatmap.get_xticklabels(),rotation=90)
# Out:
# <ipython-input-46-72bdffc89251>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_df=df_track.drop(["key","mode","explicit"],axis=1).corr(method="pearson")
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'danceability'),
#  Text(2.5, 0, 'energy'),
#  Text(3.5, 0, 'loudness'),
#  Text(4.5, 0, 'speechiness'),
#  Text(5.5, 0, 'acousticness'),
#  Text(6.5, 0, 'instrumentalness'),
#  Text(7.5, 0, 'liveness'),
#  Text(8.5, 0, 'valence'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'time_signature'),
#  Text(11.5, 0, 'duration')]

# %%
sample_df=df_track.sample(int(0.004*len(df_track)))
sample_df.head()
# Out:
#                            id  \
# 25492  0rWFTeLVPns31FX7yi4RwY
# 19639  6xAcx1w22fWpcfeOFuwuCL
# 9097   3Nr6pKx8BC77I6oKj9C5tu
# 32323  0eicQUW4H2Zv1F5c06HW7e
# 32308  3tzK95tQlY67cE8J7bU3Rm
#
#                                                     name  popularity  \
# 25492  Symphony No. 4 in E-Flat Major, WAB 104 "Roman...           0
# 19639          Nocturnes, Op. 48: No. 2 in F-Sharp Minor          11
# 9097                                Tell Me What You Are           2
# 32323                                 Babu Samjho Ishare          19
# 32308                                     I Want to Know          19
#
#        explicit                                            artists  \
# 25492         0  ['Anton Bruckner', 'Wiener Philharmoniker', 'W...
# 19639         0           ['Frédéric Chopin', 'Arthur Rubinstein']
# 9097          0                                           ['Nomy']
# 32323         0                     ['Kishore Kumar', 'Manna Dey']
# 32308         0                                    ['Ray Charles']
#
#                                               id_artists release_date  \
# 25492  ['2bM3j1JQWBkmzuoZKu4zj2', '003f4bk13c6Q3gAUXv...   1951-01-01
# 19639  ['7y97mc3bZRFXzT2szRM4L4', '5N1GUHhFMRFFgMTjSO...         1946
# 9097                          ['20bAxKr0YrCvceZeLqs37e']   1934-06-06
# 32323  ['0GF4shudTAFv8ak9eWdd4Y', '4kcoiVXIxvUoLUoHY1...   1958-01-01
# 32308                         ['1eYhYunlNJlDoQhtYBvPsi']         1958
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 25492         0.104  0.1370   3.0   -18.076   1.0       0.0464      0.834000
# 19639         0.305  0.0106   1.0   -28.085   1.0       0.0442      0.995000
# 9097          0.591  0.5050  10.0   -14.060   0.0       0.0311      0.000087
# 32323         0.728  0.5360   7.0    -9.032   1.0       0.1080      0.806000
# 32308         0.553  0.3080   6.0   -11.865   1.0       0.0601      0.753000
#
#        instrumentalness  liveness  valence    tempo  time_signature  duration
# 25492          0.714000    0.7550   0.0375   79.189             4.0      1217
# 19639          0.926000    0.1180   0.1130   78.398             4.0       432
# 9097           0.000743    0.0766   0.1340  112.993             4.0       235
# 32323          0.000000    0.0884   0.8430  123.944             4.0       290
# 32308          0.000000    0.0489   0.6210   77.752             4.0       147

# %%
len(sample_df)
# Out:
# 137

# %%
plt.figure(figsize=(10,8))
sns.regplot(data=sample_df,y="loudness",x="energy",color="c").set(title="Loudness vs Energy corr")
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy corr')]

# %%
plt.figure(figsize=(10,8))
sns.regplot(data=sample_df,y="popularity",x="acousticness",color="c").set(title="popularity vs accoustic corr")
# Out:
# [Text(0.5, 1.0, 'popularity vs accoustic corr')]

# %%
df_track["dates"]=pd.to_datetime(df_track["release_date"])
df_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34468 entries, 0 to 34467
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                34468 non-null  object
#  1   name              34468 non-null  object
#  2   popularity        34468 non-null  int64
#  3   explicit          34468 non-null  int64
#  4   artists           34468 non-null  object
#  5   id_artists        34468 non-null  object
#  6   release_date      34468 non-null  object
#  7   danceability      34467 non-null  float64
#  8   energy            34467 non-null  float64
#  9   key               34467 non-null  float64
#  10  loudness          34467 non-null  float64
#  11  mode              34467 non-null  float64
#  12  speechiness       34467 non-null  float64
#  13  acousticness      34467 non-null  float64
#  14  instrumentalness  34467 non-null  float64
#  15  liveness          34467 non-null  float64
#  16  valence           34467 non-null  float64
#  17  tempo             34467 non-null  float64
#  18  time_signature    34467 non-null  float64
#  19  duration          34468 non-null  int64
#  20  dates             34468 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(12), int64(3), object(5)
# memory usage: 5.5+ MB

# %%
df_track["release_date"]=pd.to_datetime(df_track["release_date"])
df_track["year"]=df_track["release_date"].dt.year

# %%
df_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34468 entries, 0 to 34467
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                34468 non-null  object
#  1   name              34468 non-null  object
#  2   popularity        34468 non-null  int64
#  3   explicit          34468 non-null  int64
#  4   artists           34468 non-null  object
#  5   id_artists        34468 non-null  object
#  6   release_date      34468 non-null  datetime64[ns]
#  7   danceability      34467 non-null  float64
#  8   energy            34467 non-null  float64
#  9   key               34467 non-null  float64
#  10  loudness          34467 non-null  float64
#  11  mode              34467 non-null  float64
#  12  speechiness       34467 non-null  float64
#  13  acousticness      34467 non-null  float64
#  14  instrumentalness  34467 non-null  float64
#  15  liveness          34467 non-null  float64
#  16  valence           34467 non-null  float64
#  17  tempo             34467 non-null  float64
#  18  time_signature    34467 non-null  float64
#  19  duration          34468 non-null  int64
#  20  dates             34468 non-null  datetime64[ns]
#  21  year              34468 non-null  int64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(4)
# memory usage: 5.8+ MB

# %%
sns.displot(df_track["year"],discrete=True,aspect=2,height=5,kind="hist").set(title="Number of song per year")

# %%
total_dr=df_track["duration"]
fig,ax=plt.subplots()
fig=sns.barplot(x=df_track["year"],y=total_dr,ax=ax,errwidth=False).set(title="Year vs Duration")

# %%
sns.set_style(style="whitegrid")
fig_dims=(10,5)
fig,ax=plt.subplots(figsize=fig_dims)
fig=sns.lineplot(x=df_track["year"],y=total_dr,ax=ax).set(title="year vs duration")
plt.xticks(rotation=60)
# Out:
# (array([1920., 1925., 1930., 1935., 1940., 1945., 1950., 1955., 1960.,
#         1965.]),
#  [Text(1920.0, 0, '1920'),
#   Text(1925.0, 0, '1925'),
#   Text(1930.0, 0, '1930'),
#   Text(1935.0, 0, '1935'),
#   Text(1940.0, 0, '1940'),
#   Text(1945.0, 0, '1945'),
#   Text(1950.0, 0, '1950'),
#   Text(1955.0, 0, '1955'),
#   Text(1960.0, 0, '1960'),
#   Text(1965.0, 0, '1965')])

# %%
df=pd.read_csv("/content/SpotifyFeatures.csv")
df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV         0.0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP         1.0         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy         3.0         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf         0.0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK         4.0         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0      99373.0   0.910             0.000  C#    0.3460    -1.828  Major
# 1     137373.0   0.737             0.000  F#    0.1510    -5.559  Minor
# 2     170267.0   0.131             0.000   C    0.1030   -13.879  Minor
# 3     152427.0   0.326             0.000  C#    0.0985   -12.178  Major
# 4      82625.0   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
plt.title("Duration of song in diff geners")
sns.color_palette("rocket",as_cmap=True)
sns.barplot(y=df["genre"],x=df["duration_ms"],data=df)
plt.xlabel("Duration in milli second")
plt.ylabel("Geners")
# Out:
# Text(0, 0.5, 'Geners')

# %%
sns.set_style(style="darkgrid")
plt.figure(figsize=(10,5))
famous=df.sort_values("popularity",ascending=False).head(10)
sns.barplot(y="genre",x="popularity",data=famous).set(title="top 10 genres by popularity")
# Out:
# [Text(0.5, 1.0, 'top 10 genres by popularity')]
